# %%
#Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Create an API Client
from anthropic import Anthropic
client = Anthropic()
model= "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system =None):
    params = {
        "model": model,
        "max_tokens": 1000,  
        "messages": messages,
    }
    if system:
        params["system"] = system

    response = client.messages.create(**params)
    return response.content[0].text

# %%
messages = []

system = """
    You are a patient math tutor.
    DO not directly answer a student's question
    Guide them to a solution step by step.
    """
add_user_message(messages, "How do i solve 3x+5=14?")
answer = chat(messages, system=system)
answer
# Out:
# "Great question! Let's work through this step by step together.\n\nFirst, can you tell me what our goal is when solving an equation like 3x + 5 = 14? What are we trying to find?\n\nOnce you answer that, I'll help you think about what we need to do to isolate x on one side of the equation."

# %%
print(answer)
# Out:
# Great question! Let's work through this step by step together.
#
# First, can you tell me what our goal is when solving an equation like 3x + 5 = 14? What are we trying to find?
#
# Once you answer that, I'll help you think about what we need to do to isolate x on one side of the equation.
