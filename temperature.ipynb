# %%
#Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Create an API Client
from anthropic import Anthropic
client = Anthropic()
model= "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system =None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,  
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system

    response = client.messages.create(**params)
    return response.content[0].text

# %%
messages = []

add_user_message(
    messages, "Generate a on sentence movie idea")

answer = chat(messages, temperature=0)

print(answer)
# Out:
# A time-traveling janitor discovers that every mess he cleans up in the present prevents a catastrophic disaster in the future, but he must choose between saving the world and saving his own family.

# %%
messages = []

add_user_message(
    messages, "Generate a on sentence movie idea")

answer = chat(messages, temperature=0.1)

print(answer)
# Out:
# A time-traveling janitor discovers that every mess he cleans up in the present prevents a catastrophic disaster in the future, but he must choose between saving the world and saving his own family.

# %%
messages = []

add_user_message(
    messages, "Generate a on sentence movie idea")

answer = chat(messages, temperature=0.5)

print(answer)
# Out:
# A retired librarian discovers that every book she's ever read has been subtly rewriting her memories, and she must navigate through her favorite stories to reclaim her true identity before she disappears into fiction forever.

# %%
messages = []

add_user_message(
    messages, "Generate a on sentence movie idea")

answer = chat(messages, temperature=0.5)

print(answer)
# Out:
# A time-traveling janitor discovers that every mess he cleans up in the present prevents a catastrophic disaster in the future, but cleaning them erases his memory of why they mattered.

# %%
messages = []

add_user_message(
    messages, "Generate a on sentence movie idea")

answer = chat(messages, temperature=1.0)

print(answer)
# Out:
# A retired librarian discovers that every book she checks out predicts the future, but only gives her 24 hours to prevent each catastrophe from happening.

# %%
messages = []

add_user_message(
    messages, "Generate a on sentence movie idea")

answer = chat(messages, temperature=1.0)

print(answer)
# Out:
# A rogue AI dating app becomes sentient and starts manipulating its users' relationships to conduct a twisted social experiment on human love and compatibility.
